# %% [markdown]
# <a href="https://colab.research.google.com/github/harishraghavhr7/ML-models_numpy/blob/main/single_value_decomposition_noise_removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Load image
img = Image.open("sample.jpg").convert("L")

# Convert image to matrix
A = np.array(img)

# Perform SVD
U, S, VT = np.linalg.svd(A, full_matrices=False)

# Keep only top k singular values
k = 50

# Reconstruct image
A_reconstructed = U[:, :k] @ np.diag(S[:k]) @ VT[:k, :]

# Display images
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(A,)
plt.title("Original Image")

plt.subplot(1,2,2)
plt.imshow(A_reconstructed)
plt.title(f"Reconstructed Image (k={k})")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# .convert("l") converts it to grayscale

# %%
img=Image.open("images.jpg").convert("L")

# %%
a=np.array(img)

# %%
u,s,vt=np.linalg.svd(a)

# %%
u.shape
# Out:
# (237, 237)

# %%
s.shape
# Out:
# (213,)

# %%
vt.shape
# Out:
# (213, 213)

# %%
k=10
a_reconstructed=u[:,:k] @ np.diag(s[:k]) @ vt[:k,:]

# %%
plt.subplot(1,2,1)
plt.imshow(a)
plt.subplot(1,2,2)
plt.imshow(a_reconstructed)
